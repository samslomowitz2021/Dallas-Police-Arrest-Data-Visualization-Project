# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import linregress
import seaborn as sns

file = pd.read_csv("Data/Dallas_Police_Arrests.csv")

file.head()
# Out:
#    IncidentNum  Arrest Year Arrest Date  Arrest Time         Arrest Address  \
# 0  110555-2019         2019    6/2/2019   4:45:00 PM   500 E JEFFERSON BLVD
# 1  152471-2019         2019   7/28/2019   8:40:00 PM         4800 MAPLE AVE
# 2  235407-2021         2021  12/31/2021   9:11:00 PM   13165 N CENTRAL EXPY
# 3  154267-2018         2018   7/15/2018  12:10:00 AM          1800 CADIZ ST
# 4  087877-2018         2018   4/26/2018   2:22:00 PM  9304 HARRY HINES BLVD
#
#    Arrest Zipcode  Latitude  Longitude  Arrest City Arrest State  \
# 0           75203    32.7758   -96.7967      Dallas        Texas
# 1           75235    32.7758   -96.7967      Dallas        Texas
# 2           75243    32.7758   -96.7967      Dallas        Texas
# 3           75201    32.7758   -96.7967      Dallas        Texas
# 4           75220    32.7758   -96.7967      Dallas        Texas
#
#   Arrest Day of The Week  Arrest Location Arrest Weapon  \
# 0                     Sun           Other       Unarmed
# ...

# %%
sns.histplot(data=file, x="Arrest Year")
# Out:
# <AxesSubplot:xlabel='Arrest Year', ylabel='Count'>

# %%
file.describe()
# Out:
#         Arrest Year  Arrest Zipcode     Latitude   Arrestee Age At Arrest Time
# count  61656.000000    61656.000000  61612.000000                 61656.000000
# mean    2017.742604    75218.697807     32.776587                    35.073845
# std        2.267065      408.667364      0.144953                    12.059544
# min     2014.000000        0.000000     30.770600                    18.000000
# 25%     2016.000000    75210.000000     32.775800                    25.000000
# 50%     2018.000000    75219.000000     32.775800                    32.000000
# 75%     2020.000000    75231.000000     32.775800                    43.000000
# max     2022.000000    78225.000000     57.650100                    91.000000
